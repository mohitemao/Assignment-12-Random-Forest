# %%
#import the require librarie
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# load data set
df=pd.read_csv("C:/Users/hp/Desktop/DATA SCIENCE COURSE/ASSIGNMENT/ASSIGNMENT 12/Company_Data.csv")
df
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sales        400 non-null    float64
#  1   CompPrice    400 non-null    int64
#  2   Income       400 non-null    int64
#  3   Advertising  400 non-null    int64
#  4   Population   400 non-null    int64
#  5   Price        400 non-null    int64
#  6   ShelveLoc    400 non-null    object
#  7   Age          400 non-null    int64
#  8   Education    400 non-null    int64
#  9   Urban        400 non-null    object
#  10  US           400 non-null    object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 34.5+ KB

# %%
df.describe()
# Out:
#             Sales   CompPrice      Income  Advertising  Population  \
# count  400.000000  400.000000  400.000000   400.000000  400.000000
# mean     7.496325  124.975000   68.657500     6.635000  264.840000
# std      2.824115   15.334512   27.986037     6.650364  147.376436
# min      0.000000   77.000000   21.000000     0.000000   10.000000
# 25%      5.390000  115.000000   42.750000     0.000000  139.000000
# 50%      7.490000  125.000000   69.000000     5.000000  272.000000
# 75%      9.320000  135.000000   91.000000    12.000000  398.500000
# max     16.270000  175.000000  120.000000    29.000000  509.000000
#
#             Price         Age   Education
# count  400.000000  400.000000  400.000000
# mean   115.795000   53.322500   13.900000
# std     23.676664   16.200297    2.620528
# min     24.000000   25.000000   10.000000
# 25%    100.000000   39.750000   12.000000
# 50%    117.000000   54.500000   14.000000
# 75%    131.000000   66.000000   16.000000
# ...

# %%
plt.rcParams['figure.figsize']=[10,4]
sns.countplot(x='Urban',data=df)
# Out:
# <AxesSubplot:xlabel='Urban', ylabel='count'>

# %% [markdown]
# # Observation:
# 1. Stores are more in Urban areas as compared to Rural area

# %%
sns.countplot(x='ShelveLoc',data=df)
# Out:
# <AxesSubplot:xlabel='ShelveLoc', ylabel='count'>

# %%
sns.countplot(x='US',data=df)
# Out:
# <AxesSubplot:xlabel='US', ylabel='count'>

# %% [markdown]
# 1. more store are located in US

# %%
df.columns
# Out:
# Index(['Sales', 'CompPrice', 'Income', 'Advertising', 'Population', 'Price',
#        'ShelveLoc', 'Age', 'Education', 'Urban', 'US'],
#       dtype='object')

# %%
# checking the outlier in continuos features
plt.rcParams['figure.figsize']=[15,6]
df[['Sales', 'CompPrice', 'Income', 'Advertising', 'Population', 'Price','Age', 'Education']].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
# handling the categorical features
df1=pd.get_dummies(data=df,columns=['ShelveLoc','Urban', 'US'])
df1
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0     9.50        138      73           11         276    120   42         17
# 1    11.22        111      48           16         260     83   65         10
# 2    10.06        113      35           10         269     80   59         12
# 3     7.40        117     100            4         466     97   55         14
# 4     4.15        141      64            3         340    128   38         13
# ..     ...        ...     ...          ...         ...    ...  ...        ...
# 395  12.57        138     108           17         203    128   33         14
# 396   6.14        139      23            3          37    120   55         11
# 397   7.41        162      26           12         368    159   40         18
# 398   5.94        100      79            7         284     95   50         12
# 399   9.71        134      37            0          27    120   49         16
#
# ...

# %%
corr=df1.corr()

# %%
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Converting  the continuos feature sale into cattegorical feature by grouping as good sale or bad sale
#
# ## sales >= 7.496 will be good sale and less than that will be bad sale.

# %%
df1['sale']='Good'
df1.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0   9.50        138      73           11         276    120   42         17
# 1  11.22        111      48           16         260     83   65         10
# 2  10.06        113      35           10         269     80   59         12
# 3   7.40        117     100            4         466     97   55         14
# 4   4.15        141      64            3         340    128   38         13
#
#    ShelveLoc_Bad  ShelveLoc_Good  ShelveLoc_Medium  Urban_No  Urban_Yes  \
# 0              1               0                 0         0          1
# 1              0               1                 0         0          1
# 2              0               0                 1         0          1
# 3              0               0                 1         0          1
# 4              1               0                 0         0          1
#
#    US_No  US_Yes  sale
# 0      0       1  Good
# 1      0       1  Good
# ...

# %%
df1.loc[df1['Sales']<=7.496,'sale']='Bad'
df1
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0     9.50        138      73           11         276    120   42         17
# 1    11.22        111      48           16         260     83   65         10
# 2    10.06        113      35           10         269     80   59         12
# 3     7.40        117     100            4         466     97   55         14
# 4     4.15        141      64            3         340    128   38         13
# ..     ...        ...     ...          ...         ...    ...  ...        ...
# 395  12.57        138     108           17         203    128   33         14
# 396   6.14        139      23            3          37    120   55         11
# 397   7.41        162      26           12         368    159   40         18
# 398   5.94        100      79            7         284     95   50         12
# 399   9.71        134      37            0          27    120   49         16
#
# ...

# %%
df1.drop(['Sales'],axis=1,inplace=True)
df1.head()
# Out:
#    CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0        138      73           11         276    120   42         17
# 1        111      48           16         260     83   65         10
# 2        113      35           10         269     80   59         12
# 3        117     100            4         466     97   55         14
# 4        141      64            3         340    128   38         13
#
#    ShelveLoc_Bad  ShelveLoc_Good  ShelveLoc_Medium  Urban_No  Urban_Yes  \
# 0              1               0                 0         0          1
# 1              0               1                 0         0          1
# 2              0               0                 1         0          1
# 3              0               0                 1         0          1
# 4              1               0                 0         0          1
#
#    US_No  US_Yes  sale
# 0      0       1  Good
# 1      0       1  Good
# 2      0       1  Good
# ...

# %%
sns.countplot(x='sale',data=df1)
# Out:
# <AxesSubplot:xlabel='sale', ylabel='count'>

# %% [markdown]
#  1. sale data is balanced data.

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CompPrice         400 non-null    int64
#  1   Income            400 non-null    int64
#  2   Advertising       400 non-null    int64
#  3   Population        400 non-null    int64
#  4   Price             400 non-null    int64
#  5   Age               400 non-null    int64
#  6   Education         400 non-null    int64
#  7   ShelveLoc_Bad     400 non-null    uint8
#  8   ShelveLoc_Good    400 non-null    uint8
#  9   ShelveLoc_Medium  400 non-null    uint8
#  10  Urban_No          400 non-null    uint8
#  11  Urban_Yes         400 non-null    uint8
#  12  US_No             400 non-null    uint8
#  13  US_Yes            400 non-null    uint8
#  14  sale              400 non-null    object
# dtypes: int64(7), object(1), uint8(7)
# memory usage: 27.9+ KB

# %%
# split data into dependent and independent data set
x=df1.iloc[:,0:14]
x.head()
# Out:
#    CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0        138      73           11         276    120   42         17
# 1        111      48           16         260     83   65         10
# 2        113      35           10         269     80   59         12
# 3        117     100            4         466     97   55         14
# 4        141      64            3         340    128   38         13
#
#    ShelveLoc_Bad  ShelveLoc_Good  ShelveLoc_Medium  Urban_No  Urban_Yes  \
# 0              1               0                 0         0          1
# 1              0               1                 0         0          1
# 2              0               0                 1         0          1
# 3              0               0                 1         0          1
# 4              1               0                 0         0          1
#
#    US_No  US_Yes
# 0      0       1
# 1      0       1
# 2      0       1
# 3      0       1
# 4      1       0

# %%
y=df1.iloc[:,14:]
y
# Out:
#      sale
# 0    Good
# 1    Good
# 2    Good
# 3     Bad
# 4     Bad
# ..    ...
# 395  Good
# 396   Bad
# 397   Bad
# 398   Bad
# 399  Good
#
# [400 rows x 1 columns]

# %%
# spliting the data into train test data set
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %% [markdown]
# # building model using random forest

# %%
from sklearn.ensemble import RandomForestClassifier as RF
model=RF(n_jobs=4,n_estimators=150,oob_score=True,criterion='entropy')

# %%
# fit model over train  data set to check accuracy
model.fit(x_train,y_train)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_12580\162120645.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(x_train,y_train)
# RandomForestClassifier(criterion='entropy', n_estimators=150, n_jobs=4,
#                        oob_score=True)

# %%
model.oob_score_
# Out:
# 0.803125

# %%
pred_train=model.predict(x_train)

# %%
# finding accuracy score for train data
from sklearn.metrics import accuracy_score
accuracy_score(y_train,pred_train)
# Out:
# 1.0

# %%
#confusion matrix for train data
from sklearn.metrics import confusion_matrix
confusion_matrix(y_train,pred_train)
# Out:
# array([[164,   0],
#        [  0, 156]], dtype=int64)

# %%
# now we will predct data over test dataset
pred_test=model.predict(x_test)
pred_test
# Out:
# array(['Good', 'Good', 'Good', 'Good', 'Bad', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Bad', 'Good', 'Bad', 'Bad',
#        'Good', 'Good', 'Good', 'Good', 'Bad', 'Bad', 'Bad', 'Bad', 'Good',
#        'Good', 'Bad', 'Good', 'Good', 'Bad', 'Bad', 'Good', 'Good',
#        'Good', 'Good', 'Bad', 'Good', 'Good', 'Bad', 'Good', 'Bad',
#        'Good', 'Bad', 'Bad', 'Bad', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Bad', 'Good', 'Bad', 'Good', 'Good', 'Good', 'Good',
#        'Bad', 'Good', 'Good', 'Bad', 'Bad', 'Good', 'Bad', 'Bad', 'Bad',
#        'Good', 'Good', 'Bad', 'Good', 'Good', 'Good', 'Bad', 'Bad',
#        'Good', 'Bad', 'Bad', 'Bad', 'Bad', 'Good'], dtype=object)

# %%
# finding accuracy score for test data
accuracy_score(y_test,pred_test)
# Out:
# 0.7875

# %%
#confusion matrix for train data
confusion_matrix(y_test,pred_test)
# Out:
# array([[26, 11],
#        [ 6, 37]], dtype=int64)

# %%
Y_test=y_test.iloc[:,0]

# %%
pred_test
# Out:
# array(['Good', 'Good', 'Good', 'Good', 'Bad', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Bad', 'Good', 'Bad', 'Bad',
#        'Good', 'Good', 'Good', 'Good', 'Bad', 'Bad', 'Bad', 'Bad', 'Good',
#        'Good', 'Bad', 'Good', 'Good', 'Bad', 'Bad', 'Good', 'Good',
#        'Good', 'Good', 'Bad', 'Good', 'Good', 'Bad', 'Good', 'Bad',
#        'Good', 'Bad', 'Bad', 'Bad', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Bad', 'Good', 'Bad', 'Good', 'Good', 'Good', 'Good',
#        'Bad', 'Good', 'Good', 'Bad', 'Bad', 'Good', 'Bad', 'Bad', 'Bad',
#        'Good', 'Good', 'Bad', 'Good', 'Good', 'Good', 'Bad', 'Bad',
#        'Good', 'Bad', 'Bad', 'Bad', 'Bad', 'Good'], dtype=object)

# %%
# df3=pd.DataFrame({"Actual":Y_test,'Predicted':pred_test})
df3
# Out:
#     Actual Predicted
# 94    Good      Good
# 32     Bad      Good
# 225    Bad      Good
# 157   Good      Good
# 356    Bad       Bad
# ..     ...       ...
# 188   Good       Bad
# 223    Bad       Bad
# 65     Bad       Bad
# 262    Bad       Bad
# 186   Good      Good
#
# [80 rows x 2 columns]

# %% [markdown]
# # Conclusion:
# 1. over the train data model accuracy score is 100% and on test data its accuracy score is 80.3%
# 2. from confusion matrix 63 instances predicted correctly and 17 instances wrong prediction done by model

# %%
col_name=x_train.columns
features_imp=model.feature_importances_

# %%
pd.DataFrame({'features':col_name,'feature_imp':features_imp}).sort_values(by='feature_imp',ascending=False)
# Out:
#             features  feature_imp
# 4              Price     0.242531
# 5                Age     0.125657
# 0          CompPrice     0.107466
# 3         Population     0.101037
# 1             Income     0.100753
# 2        Advertising     0.091125
# 8     ShelveLoc_Good     0.071232
# 6          Education     0.057175
# 7      ShelveLoc_Bad     0.034489
# 9   ShelveLoc_Medium     0.019744
# 13            US_Yes     0.014887
# 10          Urban_No     0.012169
# 11         Urban_Yes     0.011173
# 12             US_No     0.010562

# %% [markdown]
# # Population is most important feature
